# %%
import mlflow
import dagshub
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score,classification_report,confusion_matrix

# %%
dagshub.init(repo_owner='jay-kanakia', repo_name='YouTube-comment-analyzer', mlflow=True)
mlflow.set_tracking_uri("https://dagshub.com/jay-kanakia/YouTube-comment-analyzer.mlflow")
# Out:
# Accessing as jay-kanakia
# Initialized MLflow to track repo "jay-kanakia/YouTube-comment-analyzer"
# Repository jay-kanakia/YouTube-comment-analyzer initialized!

# %%
mlflow.set_experiment(experiment_name='Exp2-BoW-vs-Tfidf')
# Out:
# 2026/01/08 07:58:54 INFO mlflow.tracking.fluent: Experiment with name 'Exp2-BoW-vs-Tfidf' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/cc111e4199a74a259076e53a93524fda', creation_time=1770977298301, experiment_id='3', last_update_time=1770977298301, lifecycle_stage='active', name='Exp2-BoW-vs-Tfidf', tags={}>

# %%
url=r'C:\Users\abc\Desktop\mlops\youtube-commment-analyzer\notebook\raw\preprocessed_data_yt_comment_analyzer.csv'
df=pd.read_csv(url)
df.head(2)
# Out:
#                                        clean_comment  category  word_count  \
# 0  family mormon never tried explain still stare ...         1          39
# 1  buddhism ha much lot compatible christianity e...         1         196
#
#    stop_word_count  char_count  punc_count
# 0               13         259           0
# 1               59        1268           0

# %%
df.drop(columns=['word_count','stop_word_count','char_count','punc_count'],inplace=True)
df.sample(2)
# Out:
#                                            clean_comment  category
# 4103   choice stark either grow productive food famin...         1
# 25039            irony never visited india according map         0

# %%
df.isnull().sum()
# Out:
# clean_comment    130
# category           0
# dtype: int64

# %%
df.dropna(subset=['clean_comment'],inplace=True)
df.isnull().sum()
# Out:
# clean_comment    0
# category         0
# dtype: int64

# %%
def run_experiment(vectorizer_type,max_features,ngram_range):

    X=vectorizer.fit_transform(df['clean_comment'])
    y=df['category']

    X_train,X_test,y_train,y_test=train_test_split()

    if vectorizer_type=='BoW':
        vectorizer=CountVectorizer(max_features=max_features,ngram_range=ngram_range)
    else:
        vectorizer=TfidfVectorizer(max_features=max_features,ngram_range=ngram_range)

    n_estimators=200
    max_depth=15
    rf=RandomForestClassifier(n_estimators=n_estimators,max_depth=max_depth)
    rf.fit(X_train,y_train)
    y_pred=rf.predict(X_test)

    score=accuracy_score(y_test,y_pred)
    recall=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    cm=confusion_matrix(y_test,y_pred)
    report=classification_report(y_test,y_pred)

    for label,metrics in report.items():
        if isinstance(metrics,dict):
            for key, value in metrics.items():
                mlflow.log_metric(f'{label}_{key},value')

    sns.
# Out:
#   Cell In[4], line 2
#     if vectorizer_type=='Bo'
#                             ^
# SyntaxError: expected ':'

# %%
W
